# %%
pip install selenium
# Out:
# ...
#      ---------------------------------------- 6.9/6.9 MB 24.6 MB/s eta 0:00:00
# ...
#      ------------------------------------- 384.9/384.9 kB 25.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium.webdriver.common.by import By
import pandas as pd

# %%
from selenium import webdriver

driver = webdriver.Chrome(executable_path = 'Users/User/Downloads/chromedriver')

url = 'https://www.facebook.com'

driver.get(url)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23140\2157649459.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = 'Users/User/Downloads/chromedriver')

# %%
url = 'https://www.facebook.com/marketplace/toronto/vehicles?maxPrice=4000&exact=false'

driver.get(url)

# %%
elements = driver.find_elements(By.CLASS_NAME,"x3ct3a4")

df = pd.DataFrame()

#df.columns = ['line_1']

for ele in elements:
    new_row = pd.Series(ele.text)
   
    df = df.append(new_row.str.split('\n', expand=True))
    
df = df.set_axis(['Price', 'Title', 'Location','Mileage','Extends'], axis=1)
df
# Out:
#       Price                   Title                        Location  \
# 0      C$37    2018 BMW 330i xdrive                     Vaughan, ON
# 0   C$3,000        2006 Ford escape                   Pickering, ON
# 0   C$2,500    2009 Hyundai elantra                     Toronto, ON
# 0   C$2,500  2010 Chevrolet equinox                 Mississauga, ON
# 0     C$150          2000 GMC t7500                     Toronto, ON
# ..      ...                     ...                             ...
# 0     C$210                   C$224  2019 Hyundai elantra preferred
# 0     C$207     2018 Honda civic LX                 Mississauga, ON
# 0     C$279                   C$310            2022 Honda accord se
# 0     C$310    2022 Honda accord se                    Brampton, ON
# 0     C$255    2020 Toyota camry se                     Toronto, ON
#
#             Mileage  Extends
# 0            70K km      NaN
# 0           291K km      NaN
# 0           165K km      NaN
# 0           339K km      NaN
# ...
